# %%
import sys
# !{sys.executable} -m pip install transformers torch sentencepiece
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 16.9 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# %%
#CHATBOT AI
from transformers import pipeline

chatbot = pipeline("text-generation", model="microsoft/DialoGPT-small")

user_input = "Hello, how are you?"

response = chatbot(
    user_input,
    max_new_tokens=50,   # ✅ use only this
    truncation=True,     # ✅ fixes warning
    pad_token_id=50256   # ✅ avoids padding warning
)

print("User:", user_input)
print("Bot:", response[0]['generated_text'])
# Out:
# Device set to use cpu
# User: Hello, how are you?
# Bot: Hello, how are you?, Hello, how could you?

# %%
#QUESTION ANSWERING
from transformers import pipeline

qa = pipeline(
    "question-answering",
    model="distilbert-base-cased-distilled-squad"   # ✅ fix warning
)

context = "India is a country in South Asia. The capital of India is New Delhi."

result = qa(
    question="What is the capital of India?",
    context=context
)

print("Answer:", result['answer'])
print("Confidence:", round(result['score'], 2))
# Out:
# Device set to use cpu
# Answer: New Delhi
# Confidence: 0.98

# %%
from transformers import pipeline

summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn"
)

text = """
Artificial Intelligence is transforming the world. It is used in healthcare,
education, transportation, and many other fields. AI helps in automation and
improves efficiency. It reduces human effort and increases productivity.
"""

summary = summarizer(
    text,
    max_length=30,     # ✅ smaller output
    min_length=10,     # ✅ ensures short summary
    do_sample=False    # ✅ better quality
)

print("Summary:", summary[0]['summary_text'])
# Out:
# Device set to use cpu
# Summary: Artificial Intelligence is transforming the world. It is used in healthcare,education, transportation, and many other fields. AI helps in automation

# %%
#MACHINE TRANSLATION
from transformers import pipeline

translator = pipeline(
    "translation_en_to_fr",
    model="Helsinki-NLP/opus-mt-en-fr"
)

text = "Machine learning is very powerful."

result = translator(
    text,
    max_length=40,     # controls output size
    truncation=True
)

print("Original:", text)
print("Translated:", result[0]['translation_text'])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\mouni\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\mouni\.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-fr. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# ...
